# %%
# Importing libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
matplotlib.__version__
# Out:
# '3.7.2'

# %%
# %matplotlib inline

# %%
# Importing data

path = r'C:\Users\katro\World Happiness Report'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'whr.csv'))

# %%
# Checking column names

df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Country', 'Region', 'Happiness Rank',
#        'Happiness Score', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Happiness Range'],
#       dtype='object')

# %%
# Creating a subset
sub = df[['Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity']]

# %%
sub
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 777            3.334                   0.35900  0.71100
# 778            3.231                   0.47600  0.88500
# 779            3.203                   0.35000  0.51700
# 780            3.083                   0.02600  0.00000
# 781            2.853                   0.30600  0.57500
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
# Creating a correlation heatmap with seaborn

f,ax = plt.subplots(figsize=(10,10))

corr = sns.heatmap(sub.corr(), annot = True, ax = ax)

# %% [markdown]
# Economy, health, and family have the strongest positive correlations to the happiness score. Generosity seems to have little impact on the happiness score.

# %%
# Creating a scatterplot to compare Happiness Score and Economy (GDP per Capita)

splot_ec = sns.lmplot(x = 'Economy (GDP per Capita)', y = 'Happiness Score', data = df)
# Out:
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# The Economy plot points are clustered closer to the Happiness Score which shows a stronger positive correlation.

# %%
# Creating a scatterplot comparing Happiness Score and Health (Life Expectancy)

splot_h = sns.lmplot(x = 'Health (Life Expectancy)', y = 'Happiness Score', data = df)
# Out:
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# The plot points for Health are showing a positive correlation, but the plot points arent closely clustered which shows it isn't very strong.

# %%
# Creating a scatterplot comparing Happiness Score and Family

splot_fam = sns.lmplot(x = 'Family', y = 'Happiness Score', data = df)
# Out:
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# While the plot points show a positive correlation, the link isn't very strong.

# %%
# Dropping column 'Unnamed: 0'

df = df.drop(columns = ['Unnamed: 0'])

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Happiness Range'],
#       dtype='object')

# %%
# Creating pair plots

pairplt = sns.pairplot(df)
# Out:
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# I want to keep exploring Economy, Health, and Family correlations.

# %%
# Using a histogram to visualize the distribution of the variable

sns.histplot(df['Happiness Score'], bins = 20, kde = True)
# Out:
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Happiness Score', ylabel='Count'>

# %%
# Creating categories of the Happiness Score

df.loc[df['Happiness Score'] < 4, 'Happiness Range'] = 'Low Happiness'

# %%
df.loc[(df['Happiness Score'] >= 4) & (df['Happiness Score'] < 6), 'Happiness Range'] = 'Medium Happiness'

# %%
df.loc[df['Happiness Score'] >= 6, 'Happiness Range'] = 'High Happiness'

# %%
df['Happiness Range'].value_counts(dropna = False)
# Out:
# Happiness Range
# Medium Happiness    451
# High Happiness      235
# Low Happiness        96
# Name: count, dtype: int64

# %%
# Creating a categorical plot in seaborn using the happiness ranges created above

sns.set(style="ticks")
cplot = sns.catplot(x="Economy (GDP per Capita)", y="Happiness Score", hue="Happiness Range", data=df)
# Out:
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\katro\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# There are many countries with lower economy scores that have high happiness. There are also  some countries with higher economy scores that have low happiness.

# %% [markdown]
# Answering questions:
# 1. Which variables are the more significant in calculating the happiness score?
#      Health, economy, and family.
# 2. What are the similarities of the countries experiencing the highest level of happiness?
#      Countries experiencing the highest level of happiness have high scores in health, economy, and family.
# 3. What are the similarities of the countries experiencing the lowest level of happiness?
#      Countries experiencing the lowest level of happiness have low scores in helath, economy, and family.

# %%
# Exporting visualizations

cplot.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'categorical_plot.png'))

# %%
corr.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'correlation_heat.png'))

# %%
splot_ec.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'scatter_econ.png'))

# %%
splot_h.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'scatter_health.png'))

# %%
splot_fam.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'scatter_family.png'))

# %%
# Exporting data

df.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'whr.csv'))

# %%
corr.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'corr.png'))
